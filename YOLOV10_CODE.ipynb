# %% [markdown]
# <a href="https://colab.research.google.com/github/MahithasriDara/yolov10/blob/main/YOLOV10_CODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import urllib.request

# Clone the repository
# !git clone https://github.com/THU-MIG/yolov10.git

# Navigate into the repository directory
os.chdir('yolov10')

# Check if setup.py or pyproject.toml exists
if os.path.exists('setup.py') or os.path.exists('pyproject.toml'):
    # Install the package
    # !pip install .
else:
    print("ERROR: Neither 'setup.py' nor 'pyproject.toml' found in the repository.")

# Navigate back to the previous directory for weights download
os.chdir('..')

# Create weights directory and download weights
weights_dir = os.path.join(os.getcwd(), 'weights')
os.makedirs(weights_dir, exist_ok=True)
urls = [
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10s.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10m.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10b.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10x.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10l.pt',
]
for url in urls:
    filename = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, filename)
    print(f'Downloaded {filename}')

# Run the YOLO command
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20304, done.
# remote: Counting objects: 100% (1347/1347), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 20304 (delta 1301), reused 1223 (delta 1222), pack-reused 18957
# Receiving objects: 100% (20304/20304), 11.18 MiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (14304/14304), done.
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
# !yolo task=detect mode=predict save=True conf=0.25 model=weights/yolov10n.pt source=/content/ran.jpeg
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
#
# image 1/1 /content/ran.jpeg: 384x640 2 0s, 5 2s, 3 3s, 110.7ms
# Speed: 14.3ms preprocess, 110.7ms inference, 374.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import os
import urllib.request

# Clone the repository
# !git clone https://github.com/THU-MIG/yolov10.git

# Navigate into the repository directory
os.chdir('yolov10')

# Check if setup.py or pyproject.toml exists
if os.path.exists('setup.py') or os.path.exists('pyproject.toml'):
    # Install the package
    # !pip install .
else:
    print("ERROR: Neither 'setup.py' nor 'pyproject.toml' found in the repository.")

# Navigate back to the previous directory for weights download
os.chdir('..')

# Create weights directory and download weights
weights_dir = os.path.join(os.getcwd(), 'weights')
os.makedirs(weights_dir, exist_ok=True)
urls = [
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10s.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10m.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10b.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10x.pt',
    'https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10l.pt',
]
for url in urls:
    filename = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, filename)
    print(f'Downloaded {filename}')

# Install YOLOv5/YOLOv8 depending on the base library you want to use.
# Here is an example of installing YOLOv5.
# !pip install ultralytics

# Run the YOLO command
# !yolo task=detect mode=train epochs=50 batch=16 plots=True model=weights/yolov10n.pt data="/content/drive/MyDrive/Traffic Object.v10-datasets-19-7-2023.yolov9/data.yaml"
# Out:
# fatal: destination path 'yolov10' already exists and is not an empty directory.
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731281 sha256=d7c94cff46ed2f7d8db44dc3e1d4656f1b9e7ef393146db0d1539754feaded80
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hohsw7yw/wheels/51/93/e8/22d2e815ced343915c15d86b2a00d95eb0a997d012527fbea7
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...
# Downloaded /content/weights/yolov10n.pt
# Downloaded /content/weights/yolov10s.pt
# Downloaded /content/weights/yolov10m.pt
# Downloaded /content/weights/yolov10b.pt
# Downloaded /content/weights/yolov10x.pt
# ...

# %%
# !yolo task=detect mode=predict save=True conf=0.25 model=/content/runs/detect/train/weights/best.pt source=/content/cars.png
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10n summary (fused): 285 layers, 2709236 parameters, 0 gradients, 8.3 GFLOPs
#
# image 1/1 /content/cars.png: 384x640 4 buss, 24 cars, 1 truck, 104.6ms
# Speed: 3.1ms preprocess, 104.6ms inference, 151.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
